# %% [markdown]
# <a href="https://colab.research.google.com/github/clumsycoder42525/Hate_speech_detector/blob/main/Hate_speech_detector.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Corrected dummy data
data = {
    'text': [
        "Let's hangout at the mall today.",
        "Preparing for an attack tomorrow.",
        "Had a great time at the beach!",
        "Bomb will explode at midnight.",
        "Studying for my exams next week.",
        "Gun is ready for the operation.",
        "Enjoying family dinner tonight.",
        "Target acquired for the mission.",
        "Had lunch with my friends today.",
        "Booked tickets for a movie night.",
        "Visiting grandma this weekend.",
        "Completed my yoga session this morning.",
        "Planning a road trip to the mountains.",
        "Just adopted a cute puppy!",
        "Finished reading an amazing novel.",
        "Attending a birthday party tonight.",
        "Excited for the cricket match tomorrow!",
        "Learning to cook Italian food these days.",
        "Weapons are stored at the base.",
        "Time for the final strike has come.",
        "Coordinates of the target are confirmed.",
        "Explosives ready for the operation.",
        "Gathering at the secret hideout tonight.",
        "Waiting for orders to begin the attack.",
        "Bomb placed near the central station.",
        "Received the package containing guns.",
        "Planning the ambush at dawn.",
        "Target elimination is scheduled for tomorrow.",
        "Went to the park with my dog today.",
        "Celebrating my sister's graduation ceremony.",
        "Cooking pasta for dinner tonight.",
        "Watching a comedy movie with friends.",
        "Visiting a museum this weekend.",
        "Planning to learn guitar this month.",
        "Going for a morning jog tomorrow.",
        "Reading a science fiction book lately.",
        "Shopping for groceries after work.",
        "Spending quality time with my family.",
        "Gardening on Sunday afternoon.",
        "Attending an online webinar on marketing.",
        "Practicing meditation for inner peace.",
        "Bought a new laptop for my studies.",
        "Cycling around the city with friends.",
        "Joined a painting class recently.",
        "Playing badminton every evening.",
        "Preparing a surprise birthday party.",
        "Trying new recipes in the kitchen.",
        "Volunteering at a local charity event.",
        "Visiting an art exhibition downtown.",
        "baking cookies with my little brother.",
        "Fixing the broken table at home.",
        "Hiking up the nearest mountain trail.",
        "Participating in a book club discussion.",
        "Delivering the explosives at the marked location.",
        "Enemy camp spotted near the bridge.",
        "Setting up weapons in the abandoned warehouse.",
        "Confirming target elimination schedule.",
        "Assembling firearms for the next mission.",
        "Securing the area for the planned attack.",
        "Secret meeting scheduled at midnight.",
        "Smuggling arms across the border tonight.",
        "Preparing the hideout for upcoming operation.",
        "Receiving coded messages from headquarters.",
        "Finalizing the plan for assassination.",
        "Testing the detonation device today.",
        "Securing escape routes after the blast.",
        "Monitoring police movements around the site.",
        "Hiding explosive devices under the car.",
        "Sabotaging communication lines tonight.",
        "Planning infiltration into restricted zones.",
        "Planting landmines near enemy base.",
        "Gathering intel for a coordinated strike.",
        "Dispatching agents for surveillance.",
        "Target spotted moving towards checkpoint.",
        "Loading weapons into the truck.",
        "Sending the encrypted attack orders.",
        "Hiding ammunition in the forest cave.",
        "Transporting chemical weapons tonight.",
        "Relaxing with a cup of coffee this evening.",
        "Setting traps around the target area.",
        "Learning Spanish through online courses.",
        "Making homemade pizza for dinner.",
        "Target lock confirmed, awaiting final orders.",
        "Practicing yoga in the park daily.",
        "Sending surveillance drones to the site.",
        "Attending a friend's wedding this weekend.",
        "Equipping agents with advanced weaponry.",
        "Chilling at home with Netflix and popcorn.",
        "Mapping out the escape route after the mission.",
        "Organizing a charity run for the local community.",
        "Preparing chemical agents for the next strike.",
        "Joining an online photography course.",
        "Sending out coded signals from the base.",
        "Planning a camping trip with cousins.",
        "Transporting explosives to the safe house.",
        "Painting a new artwork for the exhibition.",
        "Setting up ambush near the enemy outpost.",
        "Going for a swim at the local pool.",
        "Encrypting all the communication channels.",
        "Trying a new restaurant downtown.",
        "Smuggling contraband through the secret tunnel.",
        "Relaxing with family at the beach resort.",
        "Developing plans for coordinated attacks.",
        "Baking a chocolate cake for my brother.",
        "Securing the perimeter for incoming assault.",
        "Playing the guitar in the evening.",
        "Dispatching armored vehicles for the operation.",
        "Reading a historical novel before bed.",
        "Preparing grenades for the upcoming assault.",
        "Walking my dog in the neighborhood park.",
        "Establishing contact with undercover agents.",
        "Cycling with friends around the lake.",
        "Training recruits for the secret mission.",
        "Meditating every morning to stay focused.",
        "Finalizing blueprints for the covert mission.",
        "Planning a family road trip across the country.",
        "Exploring local food markets in the city.",
        "Checking weapon stock before deployment.",
        "Participating in a marathon next month.",
        "Arranging tactical supplies for the unit.",
        "Hosting a barbecue party on Sunday.",
        "Loading explosives onto hidden compartments.",
        "Practicing photography at sunset.",
        "Preparing fake identities for agents.",
        "Shopping for Christmas gifts with friends.",
        "Installing surveillance cameras around the building.",
        "Going to the amusement park with cousins.",
        "Watching the sunset at the beach.",
        "Received shipment of explosives today.",
        "Baking a cake for my best friend's birthday.",
        "Hiding weapons in the old barn.",
        "Shopping for new clothes at the mall.",
        "Meeting secret agents at the docks tonight.",
        "Trying out a new sushi place downtown.",
        "Planning an unauthorized infiltration tonight.",
        "Bought tickets for the football match.",
        "Preparing bombs for the next assault.",
        "Cleaning my room this weekend.",
        "Storing guns inside the abandoned factory.",
        "Watching a documentary on wildlife.",
        "Target neutralization scheduled for 6 AM.",
        "Playing video games with cousins.",
        "Installing surveillance cameras around the area.",
        "Visiting the library for project research.",
        "Testing explosive devices at secret lab.",
        "Reading a novel before sleeping.",
        "Planning a hostage rescue mission.",
        "Joining dance classes from next week.",
        "Smuggling illegal arms across the river.",
        "Having dinner with old friends.",
        "Preparing the armored vehicle for attack.",
        "Attending an online course on marketing.",
        "Fabricating fake IDs for the operation.",
        "Gardening on the rooftop garden.",
        "Scheduling the final strike meeting.",
        "Organizing a family picnic this Sunday.",
        "Transporting grenades in hidden compartments.",
        "Learning new photography techniques.",
        "Collecting intelligence on enemy movements.",
        "Camping with college friends this summer.",
        "Monitoring targets using satellite feeds.",
        "Making DIY crafts at home.",
        "Building hidden compartments for smuggling.",
        "Enjoying pizza night with siblings.",
        "Planning cross-border infiltration next week.",
        "Watching a stand-up comedy show.",
        "Target map finalized for the raid.",
        "Jogging in the park every morning.",
        "Receiving secret codes from the headquarters.",
        "Painting my room with bright colors.",
        "Tracking police patrols in the area.",
        "Cycling with friends on Sunday morning.",
        "Installing booby traps around the hideout.",
        "Attending a friend's wedding ceremony.",
        "Setting explosive charges at target sites.",
        "Practicing yoga daily for fitness.",
        "Reinforcing security at the safehouse."
    ],
    'label': [
        "Safe",
        "Suspicious",
        "Safe",
        "Suspicious",
        "Safe",
        "Suspicious",
        "Safe",
        "Suspicious",
        "Safe",
        "Safe",
        "Safe",
        "Safe",
        "Safe",
        "Safe",
        "Safe",
        "Safe",
        "Safe",
        "Suspicious",
        "Suspicious",
        "Suspicious",
        "Suspicious",
        "Suspicious",
        "Suspicious",
        "Suspicious",
        "Suspicious",
        "Suspicious",
        "Suspicious",
        "Suspicious",
        "Safe",
        "Safe",
        "Safe",
        "Safe",
        "Safe",
        "Safe",
        "Safe",
        "Safe",
        "Safe",
        "Safe",
        "Safe",
        "Safe",
        "Safe",
        "Safe",
        "Safe",
        "Safe",
        "Safe",
        "Safe",
        "Safe",
        "Safe",
        "Safe",
        "Safe",
        "Safe",
        "Safe",
        "Suspicious",
        "Suspicious",
        "Suspicious",
        "Suspicious",
        "Suspicious",
        "Suspicious",
        "Suspicious",
        "Suspicious",
        "Suspicious",
        "Suspicious",
        "Suspicious",
        "Suspicious",
        "Suspicious",
        "Suspicious",
        "Suspicious",
        "Suspicious",
        "Suspicious",
        "Suspicious",
        "Suspicious",
        "Suspicious",
        "Suspicious",
        "Suspicious",
        "Suspicious",
        "Suspicious",
        "Suspicious",
        "Suspicious",
        "Safe",
        "Suspicious",
        "Safe",
        "Safe",
        "Suspicious",
        "Safe",
        "Suspicious",
        "Safe",
        "Suspicious",
        "Safe",
        "Suspicious",
        "Safe",
        "Suspicious",
        "Safe",
        "Suspicious",
        "Safe",
        "Suspicious",
        "Safe",
        "Suspicious",
        "Safe",
        "Suspicious",
        "Safe",
        "Suspicious",
        "Safe",
        "Suspicious",
        "Safe",
        "Suspicious",
        "Safe",
        "Suspicious",
        "Safe",
        "Suspicious",
        "Safe",
        "Suspicious",
        "Safe",
        "Suspicious",
        "Safe",
        "Safe",
        "Suspicious",
        "Safe",
        "Suspicious",
        "Safe",
        "Suspicious",
        "Safe",
        "Suspicious",
        "Safe",
        "Suspicious",
        "Safe",
        "Suspicious",
        "Safe",
        "Safe",
        "Suspicious",
        "Safe",
        "Suspicious",
        "Safe",
        "Suspicious",
        "Safe",
        "Suspicious",
        "Safe",
        "Suspicious",
        "Safe",
        "Suspicious",
        "Safe",
        "Suspicious",
        "Safe",
        "Suspicious",
        "Safe",
        "Suspicious",
        "Safe",
        "Suspicious",
        "Safe",
        "Suspicious",
        "Safe",
        "Suspicious",
        "Safe",
        "Suspicious",
        "Safe",
        "Suspicious",
        "Safe",
        "Suspicious",
        "Safe",
        "Suspicious",
        "Safe",
        "Suspicious",
        "Safe",
        "Suspicious",
        "Safe",
        "Suspicious",
        "Safe",
        "Suspicious",
        "Safe",
        "Suspicious",
        "Safe",
        "Suspicious",
        "Safe",
        "Suspicious",
        "Safe",
        "Suspicious",
        "Safe",
        "Suspicious"
    ]
}

df = pd.DataFrame(data)

print(df)
# Out:
#                                            text       label
# 0              Let's hangout at the mall today.        Safe
# 1             Preparing for an attack tomorrow.  Suspicious
# 2                Had a great time at the beach!        Safe
# 3                Bomb will explode at midnight.  Suspicious
# 4              Studying for my exams next week.        Safe
# ..                                          ...         ...
# 172  Installing booby traps around the hideout.  Suspicious
# 173      Attending a friend's wedding ceremony.        Safe
# 174  Setting explosive charges at target sites.  Suspicious
# 175          Practicing yoga daily for fitness.        Safe
# 176      Reinforcing security at the safehouse.  Suspicious
#
# [177 rows x 2 columns]

# %%
from sklearn.preprocessing import OrdinalEncoder
oe=OrdinalEncoder()

# %%
from sklearn.preprocessing import OrdinalEncoder
from sklearn.compose import make_column_transformer
ct = make_column_transformer(
    (oe, ["label"]),
    remainder="passthrough"
)
ct.fit_transform(df)
# Out:
# array([[0.0, "Let's hangout at the mall today."],
#        [1.0, 'Preparing for an attack tomorrow.'],
#        [0.0, 'Had a great time at the beach!'],
#        [1.0, 'Bomb will explode at midnight.'],
#        [0.0, 'Studying for my exams next week.'],
#        [1.0, 'Gun is ready for the operation.'],
#        [0.0, 'Enjoying family dinner tonight.'],
#        [1.0, 'Target acquired for the mission.'],
#        [0.0, 'Had lunch with my friends today.'],
#        [0.0, 'Booked tickets for a movie night.'],
#        [0.0, 'Visiting grandma this weekend.'],
#        [0.0, 'Completed my yoga session this morning.'],
#        [0.0, 'Planning a road trip to the mountains.'],
#        [0.0, 'Just adopted a cute puppy!'],
#        [0.0, 'Finished reading an amazing novel.'],
#        [0.0, 'Attending a birthday party tonight.'],
#        [0.0, 'Excited for the cricket match tomorrow!'],
#        [1.0, 'Learning to cook Italian food these days.'],
# ...

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
X = df['text']
y = df['label']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vc = TfidfVectorizer()
X_vectorized = vc.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
X_train, X_test, y_train, y_test = train_test_split(X_vectorized, y, test_size=0.2, random_state=42)

rfc = RandomForestClassifier()
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
while True:
    custom_sentence = input("Enter a sentence (or type 'exit' to quit): ")
    if custom_sentence.lower() == 'exit':
        print("Exiting... 👋")
        break
    custom_vector = vectorizer.transform([custom_sentence])
    custom_prediction = rfc.predict(custom_vector)
    print(f"You entered: {custom_sentence} → Prediction: {custom_prediction[0]}")
    print("-" * 50)
# Out:
# Enter a sentence (or type 'exit' to quit): my name is john
# You entered: my name is john → Prediction: Safe
# --------------------------------------------------
# Enter a sentence (or type 'exit' to quit): we are organising a secret meeting
# You entered: we are organising a secret meeting → Prediction: Suspicious
# --------------------------------------------------
# Enter a sentence (or type 'exit' to quit): exit
# Exiting... 👋
